# %% [markdown]
# #**Classification of Supply Chain Data into {Segments | Clusters | Classes} using Cross-Validation and Ensemble Methods**
#
# ##**1. Project Objectives | Problem Statements**
#
#   1.1. PO1 | PS1: Classification of Customer Data into Segments | Clusters | Classes using Supervised Learning Classification Algorithms
#
#   1.2. PO2 | PS2: Determination of an Appropriate Classification Model
#
#   1.3. PO3 | PS3: Identification of Important | Contributing | Significant Variables or Features and their Thresholds for Classification
#
#
# ##**2. Description of Data**
#
# **2.1. Data Source, Size, Shape**
#
# 2.1.1. Data Source (https://www.kaggle.com/datasets/shashwatwork/dataco-smart-supply-chain-for-big-data-analysis)
#
# 2.1.2. Data Size (17.5 MB)
#
# 2.1.3. Data Shape (Dimension: Number of Variables - 12 | Number of Records - 98347 rows × 12 columns)
#
#
# **2.2. Description of Variables**
#
# **2.2.1. Index Variable(s)**
#
# Index Variable(s): Column1
#
# **2.2.2 Variables or Features having Categories | Categorical Variables or Features (CV)**
#
# 2.2.2.1. Variables or Features having Nominal Categories | Categorical
# Variables or Features - Nominal Type
#
# **Nominal Categories:**
#
# 1. Type
#
# 2. Customer Segment
#
# 3. Market
#
# 4. Order Country
#
# 5. Shipping Mode
#
# 6. cluster_number
#
# 2.2.2.2. Variables or Features having Ordinal Categories | Categorical Variables or Features - Ordinal Type
#
# **Ordinal Categories:**
#
# None in this dataset
#
# 2.2.3. Non-Categorical Variables or Features Non-Categorical Variables or Features:
#
# 1. Sales per customer
#
# 2. Order Item Cardprod Id
#
# 3. Sales
#
# 4. Order Item Total
#
# 5. Product Price
#
#
# **Variable Description:**
#
# **Index Variable:**
#
# Column1 - The serial no. from 1 to 98347
#
# **Categorical Variables:**
#
# - Nominal Categories:
#
# 1. Type - Type of the payment methods used by he customers (DEBIT, TRANFER, CASH)
#
# 2. Customer Segment - Customers are classified as consumer, Home office or corporate.
#
# 3. Market - The market from where the customers belong (Pacific Asia, USCA, Africa, Europe, LATAM)
#
# 4. Order Country - The country from where the orders come (Indonesia, India, Australia, China, Singapur, Mexico)
#
# 5. Shipping Mode -  The class of the shipping mode (Standard class, First Class, Second Class, Same Day)
#
# 6. cluster_number - No. of cluster
#
# - Ordinal Categories: None in the dataset
#
# **Non-Categorical Variables:**
#
# 1. Sales per customer - The sales by each customer
#
# 2. Order Item Cardprod Id - The id of the order.
#
# 3. Sales - The revenue earned.
#
# 4. Order Item Total - The total order recieved.
#
# 5. Product Price - The price of the products purchased.
#
#
# **2.3. Descriptive Statistics**
#
# **2.3.1. Descriptive Statistics: Outcome Variable or Feature (Categorical)**
#
# 2.3.1.1. Count | Frequency Statistics:
#
# - Count of each cluster category:
#
#   Cluster 0 -     43990
# Cluster 1  -    30573
# Cluster 2  -       23784
#
#
# 2.3.1.2. Proportion (Relative Frequency) Statistics:
# - Proportion of each cluster category:
#
#    Cluster 0       -        0.447294
# Cluster  1     -     0.310869
#
#   Cluster 2      -    0.241838
#
#
# **2.3.2. Descriptive Statistics: Input Categorical Variables or Features**
#
# 2.3.2.1. Count | Frequency Statistics:
# - Count of each category for categorical variables:
#
# 1. Type
#
#   DEBIT - 45432
#
#    CASH - 12486
#
#   TRANFER - 16989
#
#   PAYEMNT - 23440
#
#
# 2. Customer Segment
#
#  Consumer - 45586
#
#  Corporate - 41541
#
#  Home Office - 11220
#
# 3. Market
#
#  LATAM - 28547
#
#  Europe - 28259
#
#  Pacific Asia - 22064
#
#  USCA - 13431
#
#  Africa - 6046
#
# 4. Order Country
#
#  Mexico - 7304
#
#  Francia - 7624
#
#  Kuwait - 1
#
#  .
#
#  .
#
#  Burundi - 1
#
# 5. Shipping Mode
#
#  Standard Class - 56800
#
#  Second Class - 20460
#
#  First Class - 15877
#
#  Same day - 5210
#
# 2.3.2.2. Proportion (Relative Frequency) Statistics:
# - Proportion of each category for categorical variables:
#
# 1. Type
#
#   DEBIT - 46.0
#
#    CASH - 13.0
#
#   TRANFER - 17.0
#
#   PAYEMNT - 24.0
#
#
# 2. Customer Segment
#
#  Consumer - 46.0
#
#  Corporate - 42.0
#
#  Home Office - 11.0
#
# 3. Market
#
#  LATAM -  29.0
#
#  Europe - 29.0
#
#  Pacific Asia - 22.0
#
#  USCA - 14.0
#
#  Africa - 6.0
#
# 4. Order Country
#
#  Mexico - 7.0
#
#  Francia - 8.0
#
#  Kuwait - 0.0
#
#  .
#
#  .
#
#  Burundi -  0.0
#
# 5. Shipping Mode
#
#  Standard Class - 58.0
#
#  Second Class - 21.0
#
#  First Class - 16.0
#
#  Same day -    5.0
#
# **2.3.3. Descriptive Statistics: Input Non-Categorical Variables or Features**
#
# 2.3.3.1. Measures of Central Tendency:
# - Mean, Median (50th percentile), and Mode for numeric variables:
#
# **Mean Values:**
#
# 1. Sales per customer - 175.75
#
# 2. Order Item Cardprod Id - 656.47
#
# 3. Sales - 195.67
#
# 4. Order Item Total - 175.75
#
# 5. Product Price - 136.59
#
#
# **Median Values:**
#
# 1. Sales per customer - 161.97
#
# 2. Order Item Cardprod Id - 502.00
#
# 3. Sales - 199.94
#
# 4. Order Item Total - 161.97
#
# 5. Product Price - 99.98
#
#
# **Mode Values:**
#
# 1. Sales per customer    -    107.88
#
# 2. Order Item Cardprod Id  -  365.00
#
# 3. Sales               -      129.99
#
# 4. Order Item Total   -       107.88
#
# 5. Product Price      -        59.99
#
# 2.3.3.2. Measures of Dispersion:
#
# **Standard Deviation**
#
# 1. Sales per customer - 118.80
#
# 2. Order Item Cardprod Id - 340.42
#
# 3. Sales - 131.11
#
# 4. Order Item Total - 118.80
#
# 5. Product Price - 132.39
#
# **Range (Maximum - Minimum )**
#
# 1. Sales per customer - (1919.98 - 7.49)
#
# 2. Order Item Cardprod Id - (1363.00 - 19.00)
#
# 3. Sales - (1999.98 - 9.99)
#
# 4. Order Item Total - (1919.98 - 7.49)
#
# 5. Product Price - (1999.98 - 9.99)
#
# 2.3.3.3. Correlation Statistics (with Test of Correlation)
# - Correlation coefficients between numeric variables:
#
# 1. Sales per customer vs Order Item Cardprod Id - 0.183842
#
# 2. Sales per customer vs Sales - 0.989953
#
# 3. Sales per customer vs Order Item Total - 1.0000
#
# 4. Sales per customer vs Product Price - 0.729716
#
# 5. Order Item Cardprod Id vs Sales - 0.186169
#
# 6. Order Item Cardprod Id vs Order Item Total - 0.183842
#
# 7. Order Item Cardprod Id vs Product Price - 0.542560
#
# 8. Product Price vs Order Item Total - 0.729716
#
# ##**3. Analysis**
#
# **3.1. Data Pre-Processing**
#
# **3.1.1. Missing Data Statistics and Treatment**
# - Variable-wise Missing Data Information:
#    - No missing data in any variable.
#
# - Record-wise Missing Data Information (Top 5 Records):
#    - No records with missing data.
#
#  **3.1.2. Numerical Encoding of Categorical Variables or Features**
# - Ordinal Encoder:
#    - Categorical variables were encoded into numerical format using Ordinal Encoder.
#
# **3.1.3. Outlier Statistics and Treatment**
# - Outlier Detection:
#    - Outliers were identified using boxplot visualization.
#
# - Outlier Treatment:
#    - Outliers were treated by performing normalization using Min-Max Scaler.
#
# **3.1.4. Data Transformation and Scaling**
# - Normalization:
#    - Min-Max Scaling was applied to non-categorical variables to bring them within a common scale.
#
# **3.1.5. Data Bifurcation: Training & Testing Sets**
# - Stratified Split:
#    - StratifiedShuffleSplit was utilized to split the data into training and testing sets with a test size of 20%.
#
# **Insights:**
# - The dataset did not contain any missing values either in variables or records.
# - Categorical variables were successfully encoded into numerical format using Ordinal Encoder.
# - Outliers were detected and treated using Min-Max Scaling to ensure data normalization.
# - The data was bifurcated into training and testing sets using a stratified split, maintaining the distribution of the target variable across both sets.
#
# **3.2. Data Analysis**
#
# **3.2.1.1. PO1 | PS1: Supervised Machine Learning
# Classification Algorithm: Decision Tree (Base Model) | Metrics Used - Accuracy**
#
# Accuracy: 0.48
#
# **Analysis:** Moderate to Low Performance: An accuracy of 48% suggests a performance that is not much better than random guessing, especially in scenarios where you might have multiple classes (more than two). This level of accuracy indicates that the model may struggle to reliably distinguish between the different classes based on the input features provided.
#
# **3.2.1.2. PO1 | PS1: Supervised Machine Learning Classification Algorithms: Random Forest (Comparison Model) | Metrics Used - Accuracy**
#
# For the Random Forest model:
#
# Accuracy: 0.47
#
# **Analysis:** Slightly Below Expectations: Typically, Random Forest is known for its high accuracy due to its ensemble nature, where multiple decision trees vote on the final classification. An accuracy of 47% is relatively low, especially for a model that is generally robust to overfitting and effective in handling both categorical and numerical data well.
#
# **3.2.2.1.1. PO2 | PS2: Classification Model Performance Evaluation: Confusion Matrix {Accuracy} (Base Model: Decision Tree)**
#
# For the Decision Tree model:
# Accuracy: 0.48
#
# **Analysis:** An accuracy of 0.48, or 48%, for the Decision Tree model in your classification task suggests that the model is performing slightly below what might be expected for a generally balanced dataset.
#
# **3.2.2.2.1. PO2 | PS2: Classification Model Performance Evaluation: Confusion Matrix {Accuracy} (Comparison Model: Random Forest)**
#
# For the Random Forest model:
#
# Accuracy (Training Set): 0.48
# Accuracy (Testing Set): 0.48
#
# **Analysis:** With the Random Forest model showing equal accuracy scores of 0.48 for both the training and testing sets, this consistency suggests a balanced model in terms of its ability to generalize but indicates potential areas for improvement in overall performance.
#
# **3.2.2.1.2. PO2 | PS2: Classification Model Performance Evaluation: Time Statistics | Memory Statistics (Base Model: Decision Tree)**
#
# For the Decision Tree model:
#
# Memory used (MB): 440.335 MB
# Time taken (seconds): 3.647 seconds
#
# **Analysis:**
#
# 1. Memory Usage: The model utilizes 440.335 MB of memory, which is moderate and generally manageable for most modern computing environments. This indicates that the Decision Tree model can be run on standard hardware without requiring extensive resources, making it a practical choice for environments with limited computing capacity.
#
# 2. Computational Time:The model takes approximately 3.647 seconds to train, which is relatively quick. This short duration indicates that the Decision Tree is computationally efficient, benefiting scenarios where quick model training is critical, such as in applications requiring rapid re-training with new data.
#
# - Efficiency: The efficiency of Decision Trees is one of their biggest advantages. Their ability to fit into memory and execute quickly makes them suitable for real-time applications, such as live data processing or interactive systems where decisions need to be made swiftly.
#
# - Scalability: Given the moderate memory use and fast execution, scaling this model to larger datasets should be feasible, though there will be a limit to this scalability. As the size of the data grows, the depth and complexity of the tree can increase, potentially leading to higher memory usage and longer training times.
#
# - Practicality: The current metrics suggest that the model is well-suited for practical use, especially in applications where model simplicity and speed are more critical than achieving the highest possible accuracy.
#
#
# **3.2.2.2.2. PO2 | PS2: Classification Model Performance Evaluation: Time Statistics | Memory Statistics (Comparison Model: Random Forest)**
#
# For the Random Forest model:
# Training Time (s):  11.900 seconds
# Memory Used (MB):  1427.628MB
#
# **Analysis:**
#
# 1. Training Time: The model takes approximately 11.900504 seconds to train. Compared to the base Decision Tree model, this is significantly longer, indicative of the increased computational effort required to train multiple trees in the ensemble.
#
# 2. Memory Usage: The model consumes about 1427.628906 MB of memory. This is considerably higher than that of the Decision Tree model, reflecting the additional resources required to maintain multiple decision trees and manage their outputs.
#
# - Computational Intensity: The increased training time and memory usage are typical for Random Forest due to the inherent complexity of training multiple decision trees and combining their predictions. This complexity can impact the scalability of the model, especially in resource-constrained environments.
#
# - Accuracy vs. Resource Trade-off: While Random Forests generally achieve higher accuracy and better generalization compared to a single Decision Tree by reducing variance through ensemble learning, this comes at the cost of higher computational resources. This trade-off needs careful consideration based on application needs.
#
# - Scalability Concerns: The significant memory usage suggests that scaling this model to even larger datasets might require substantial computational resources or optimized algorithms that can handle large-scale data more efficiently.
#
# **3.2.3.1. PO3 | PS3: Variable or Feature Analysis: Base Model (Decision Tree)**
#
# For the Decision Tree model:
# Relevant Variables and Thresholds:
#
# Market_code', 'Sales_mn', 'Order Item Total_mn', 'Product Price_mn: Threshold 0.1
#
# **Analysis:** These features (Market_code', 'Sales_mn', 'Order Item Total_mn', 'Product Price_mn) with a threshold of 0.1 is identified as the most relevant variable, indicating its significant impact on the Decision Tree model's predictions. This insight can guide further investigation into feature importance and model interpretability. This threshold value indicates the point of split in the decision tree where the information gain from the variable becomes significant enough to affect the tree structure. For these variables, any change above this threshold substantially impacts the model's decision pathway.
#
# Comparison between Decision Tree and Random Forest:
# Accuracy: The accuracy figures indicate very close performance between the Decision Tree and Random Forest models. The Random Forest shows a slight improvement in the training set accuracy compared to the Decision Tree. However, this improvement is minimal, suggesting that both models are similarly effective in handling the data without substantial differences in their generalization capabilities on unseen data (testing set).
#
# Time and Memory Usage: The Decision Tree model maintains its advantage in terms of computational efficiency.
#
# Feature Importance:
#
# 1. 	Market_code -	0.999
# 2.	Type_code	 - 0.000
# 3.	Customer Segment_code	- 0.000
# 4.	Shipping Mode_code - 	0.000
# 5.	Sales per customer_mn - 	0.000
# 6.	Sales_mn	- 0.000
# 7.	Order Item Total_mn	 - 0.000
# 8.	Product Price_mn	- 0.000
#
# **Analysis:**
# The feature importance analysis from the Decision Tree model strongly emphasizes the dominance of a single feature, the 'Market_code', with an importance score of 0.999. This indicates that almost all the predictive power of the model is attributed to this one feature.
#
# The overwhelming weight assigned to Market_code suggests that the market in which the transaction occurs is almost solely responsible for predictions. This could be due to a strong correlation between market characteristics and the target variable, overshadowing other features
#
# **3.2.3.2. PO3 | PS3: Variable or Feature Analysis: Comparison Model (Random Forest)**
#
# For the Random Forest model:
# Feature Importance:
#
# 1.  Market_code    0.244833
# 2.  Sales per customer_mn    0.201121
# 3. Order Item Total_mn    0.200783
# 4.       Type_code    0.103565
# 5.  Shipping Mode_code    0.083606
# 6.  Customer Segment_code    0.060216
# 7.           Sales_mn    0.053833
# 8.   Product Price_mn    0.052043
#
# **Analysis:**
#
# The analysis from the Random Forest model demonstrates its capability to provide a more comprehensive and robust analysis by incorporating a wider array of features into its decision-making process. This balanced approach not only enhances prediction accuracy but also offers actionable insights that can support more informed business decisions across multiple dimensions of the operation. As such, businesses may consider leveraging Random Forest models for deeper analytics where multiple variables interact in complex and meaningful ways.
#
# 1. Unlike the Decision Tree, where Market_code overwhelmingly dominated, the Random Forest shows a more equitable distribution of importance. Market_code still remains the most influential feature but at a significantly reduced magnitude (0.244833), suggesting that while important, the market is not the sole predictor.
#
# 2. Features like Sales per customer_mn and Order Item Total_mn also contribute significantly to the predictions, indicating their relevance in understanding the transaction dynamics. This inclusion suggests that the Random Forest is able to capture the economic aspects of transactions effectively.
#
# 3. The recognition of features like Type_code, Shipping Mode_code, and Customer Segment_code with considerable importance scores shows that the Random Forest model utilizes a broader range of data aspects, possibly leading to a richer, more accurate predictive insight.
#
# 4. The spread of importance across various operational (type, shipping mode) and customer-specific features (segment) likely reflects the Random Forest's ability to handle complex interactions and non-linear relationships within the data, which a simpler model like the Decision Tree might miss.
#
# #**4. Results | Observations**
#
# **4.1. Classification Model Parameters**
#
# Base Model (Decision Tree):
#
# Cross Validation Accuracy: 0.48
# Comparison Model (Random Forest): 0.47
# Number of Trees: 100
# Accuracy 0.47
#
# **4.2. Classification Model Performance: Time & Memory Statistics**
#
# Base Model (Decision Tree):
# Memory used (MB): 440.335 MB
# Time taken (seconds): 3.647 seconds
#
# Comparison Model (Random Forest):
# Training Time (s):  11.900 seconds
# Memory Used (MB):  1427.628MB
#
#
# **Observations:**
#
# **Decision Tree Model:**
#
# Memory Usage: The Decision Tree model utilizes 440.335 MB of memory, which is considerably lower compared to the Random Forest model. This is typical of Decision Trees, as they generally require less computational resources.
#
# Time Taken: With a computation time of just 3.647 seconds, the Decision Tree is significantly faster. This speed is due to the simpler nature of building a single tree without the need for constructing and averaging multiple models, as is the case with ensemble methods like Random Forest.
#
# **Random Forest Model:**
#
# Memory Usage: At 1427.628 MB, the Random Forest consumes much more memory than the Decision Tree. This increased memory usage is due to Random Forest building multiple decision trees (ensemble), each of which stores a subset of the data. This process intensifies the memory demand.
#
# Training Time: The Random Forest takes longer to train, with a time of 11.900 seconds. This is expected because it constructs several trees and aggregates their results to make a decision, a more resource-intensive process than building a single tree.
#
# **Analysis:**
#
# Performance vs. Precision Trade-off: The Decision Tree is quicker and uses less memory, making it suitable for situations where speed and resource efficiency are critical. However, the simplicity of a Decision Tree might come at the cost of model accuracy and the ability to handle complex patterns.
#
# Scalability and Robustness: Although the Random Forest requires more time and memory, it typically provides a more robust model by reducing the risk of overfitting seen in Decision Trees, especially in complex datasets. This makes Random Forest a better choice for applications where predictive accuracy is more important than resource constraints.
#
# **4.3. Variable or Feature Analysis**
#
# Base Model (Decision Tree):
#
# Market_code', 'Sales_mn', 'Order Item Total_mn', 'Product Price_mn: Threshold 0.1
#
# For the Random Forest model:
#
# Feature Importance:
#
# 1.  Market_code   -  0.244833
# 2.  Sales per customer_mn  -  0.201121
# 3. Order Item Total_mn   - 0.200783
# 4.       Type_code   - 0.103565
# 5.  Shipping Mode_code  -   0.083606
# 6.  Customer Segment_code   -  0.060216
# 7.           Sales_mn  -   0.053833
# 8.   Product Price_mn -   0.052043
#
# **Analysis**
#
# **Decision Tree:**
#
# 1. **Simplified Model View:** The Decision Tree simplifies the feature analysis by placing a threshold of 0.1 on the features 'Market_code', 'Sales_mn', 'Order Item Total_mn', and 'Product Price_mn'. This simplification indicates that features exceeding this threshold significantly contribute to the model decisions.
#
# 2. **Focus on Fewer Features:** The mentioned threshold highlights a critical reduction point for considering feature importance, which can signify that only a select few features strongly impact the predictions beyond a simplistic level in a Decision Tree model.
#
#
# **Random Forest:**
#
# 1. **Distributed Importance:** The Random Forest model provides a more nuanced view of feature importance, distributing relevance across a broader range of features. This is seen with 'Market_code' having the highest importance but followed closely by other sales-related metrics like 'Sales per customer_mn' and 'Order Item Total_mn'.
#
# 2. **Granular Influence:** Features such as 'Type_code', 'Shipping Mode_code', 'Customer Segment_code', 'Sales_mn', and 'Product Price_mn' also contribute significantly, albeit less than the top three. This inclusion of additional features implies a more comprehensive analysis where multiple aspects of the dataset are utilized for prediction, enhancing model robustness against overfitting and variance in data.
#
# **Comparative Insights:**
#
# 1. **Complexity and Detail:** The Random Forest model, being an ensemble method, naturally integrates a more complex and detailed understanding of how various features impact model predictions. This results in a more robust model that considers interactions between different features.
#
# 2. **Sensitivity to Feature Variations:** While the Decision Tree gives a high-stakes, clear-cut importance to few features, Random Forest's approach to distributing importance across more features helps in capturing more subtle patterns in the dataset, which might be overlooked by a single Decision Tree.
#
# 3. **Overfitting and Generalization:** Decision Trees are prone to overfitting, especially if a deep tree structure is allowed, where they might overly fit to noise in the training data. Random Forest mitigates this by averaging multiple trees, thus enhancing the generalizability of the model.
#
#
# ##**5. Managerial Insights**
#
# Real-Life Managerial Insights:
#
# 1. Market Segmentation for Targeted Marketing:
# Analyze market trends and customer purchasing patterns to segment markets based on demographics, psychographics, and buying behaviors. For instance, use clustering techniques to identify key customer groups that frequently buy certain types of products and target them with specialized marketing campaigns.
# Customize product offerings and promotions based on the preferences of different segments, thereby increasing the effectiveness of marketing strategies and boosting sales in targeted markets.
# 2. Fraud Detection and Risk Management:
# Implement anomaly detection systems to monitor transactions and detect unusual patterns that may indicate fraud, such as unexpected large orders from new clients or repeated small orders bypassing normal payment scrutiny.
# Risk assessment models can be developed to score transactions based on various factors like payment method reliability, order country risk rating, and customer historical data to proactively manage risks and mitigate potential losses.
# 3. Predictive Maintenance and Fleet Management:
# Utilize machine learning models to predict maintenance needs of transportation assets based on historical data on usage patterns and maintenance schedules. This can help in scheduling maintenance proactively to prevent breakdowns and reduce downtime.
# Optimize logistics and fleet operations by analyzing route efficiency and vehicle health data, ensuring that the fleet operates smoothly and cost-effectively, thereby enhancing overall supply chain efficiency.
# 4. Customer Lifetime Value (CLV) Prediction:
# Develop predictive models to estimate the future value of customers based on their past purchasing patterns, frequency, revenue generated, and engagement levels. This can help in identifying high-value customers for focused relationship management and personalized services.
# Tailor retention strategies based on CLV segments to maximize the profitability of each customer group, applying targeted incentives, loyalty programs, and upselling strategies where they are most likely to be effective.
# 5. Dynamic Pricing and Revenue Optimization:
# Leverage data analytics to adjust pricing in real-time based on supply and demand dynamics, competitive pricing, and inventory levels. Machine learning can be used to forecast demand and set optimal pricing points to maximize revenue while remaining competitive.
# Experiment with pricing strategies across different markets and customer segments to determine the most effective approach for various scenarios, enhancing revenue management and ensuring business adaptability in fluctuating market conditions.
# By leveraging the strengths of each classification model and applying them to real-life business scenarios, organizations can gain actionable insights, optimize decision-making processes, and drive sustainable business growth.

# %%
# Required Libraries
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation

# %%
df=pd.read_csv("RISHIKA_project2.csv")
df
# Out:
#        Column1      Type  Sales per customer Customer Segment        Market  \
# 0            0     DEBIT          314.640015         Consumer  Pacific Asia
# 1            1  TRANSFER          311.359985         Consumer  Pacific Asia
# 2            2      CASH          309.720001         Consumer  Pacific Asia
# 3            3     DEBIT          304.809998      Home Office  Pacific Asia
# 4            4   PAYMENT          298.250000        Corporate  Pacific Asia
# ...        ...       ...                 ...              ...           ...
# 98342    98342     DEBIT          224.960007      Home Office         LATAM
# 98343    98343     DEBIT          179.960007      Home Office         LATAM
# 98344    98344     DEBIT          225.000000      Home Office         LATAM
# 98345    98345     DEBIT          220.000000      Home Office         LATAM
# 98346    98346     DEBIT          224.949997      Home Office  Pacific Asia
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98347 entries, 0 to 98346
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Column1                 98347 non-null  int64
#  1   Type                    98347 non-null  object
#  2   Sales per customer      98347 non-null  float64
#  3   Customer Segment        98347 non-null  object
#  4   Market                  98347 non-null  object
#  5   Order Country           98347 non-null  object
#  6   Order Item Cardprod Id  98347 non-null  int64
#  7   Sales                   98347 non-null  float64
#  8   Order Item Total        98347 non-null  float64
#  9   Product Price           98347 non-null  float64
#  10  Shipping Mode           98347 non-null  object
#  11  cluster_number          98347 non-null  int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 9.0+ MB

# %%
# Display the data types of each column in a DataFrame
df.dtypes
# Out:
# Column1                     int64
# Type                       object
# Sales per customer        float64
# Customer Segment           object
# Market                     object
# Order Country              object
# Order Item Cardprod Id      int64
# Sales                     float64
# Order Item Total          float64
# Product Price             float64
# Shipping Mode              object
# cluster_number              int64
# dtype: object

# %%
import pandas as pd

# Assuming df is your DataFrame
categorical_columns = df.select_dtypes(include=['object']).columns
non_categorical_columns = df.select_dtypes(exclude=['object']).columns

print("Categorical Variables:")
print(categorical_columns)

print("\nNon-Categorical Variables:")
print(non_categorical_columns)
# Out:
# Categorical Variables:
# Index(['Type', 'Customer Segment', 'Market', 'Order Country', 'Shipping Mode'], dtype='object')
#
# Non-Categorical Variables:
# Index(['Column1', 'Sales per customer', 'Order Item Cardprod Id', 'Sales',
#        'Order Item Total', 'Product Price', 'cluster_number'],
#       dtype='object')

# %%
df_cat = df[['Type', 'Customer Segment', 'Market', 'Order Country', 'Shipping Mode']] # Categorical Data [Nominal | Ordinal]
df_noncat = df[['Sales per customer','Order Item Cardprod Id','Sales','Order Item Total', 'Product Price']] # Non-Categorical Data

# %%
# Count Statistics of Categorical Variables
type_stats = pd.concat([df['Type'].value_counts(), df['Type'].value_counts(normalize=True).mul(100).round(0)], axis=1, keys=('count','percentage')).reset_index()
type_stats
# Out:
#        Type  count  percentage
# 0     DEBIT  45432        46.0
# 1   PAYMENT  23440        24.0
# 2  TRANSFER  16989        17.0
# 3      CASH  12486        13.0

# %%
# Count Statistics of Categorical Variables
type_stats = pd.concat([df['Customer Segment'].value_counts(), df['Customer Segment'].value_counts(normalize=True).mul(100).round(0)], axis=1, keys=('count','percentage')).reset_index()
type_stats
# Out:
#   Customer Segment  count  percentage
# 0         Consumer  45586        46.0
# 1        Corporate  41541        42.0
# 2      Home Office  11220        11.0

# %%
# Count Statistics of Categorical Variables
type_stats = pd.concat([df['Market'].value_counts(), df['Market'].value_counts(normalize=True).mul(100).round(0)], axis=1, keys=('count','percentage')).reset_index()
type_stats
# Out:
#          Market  count  percentage
# 0         LATAM  28547        29.0
# 1        Europe  28259        29.0
# 2  Pacific Asia  22064        22.0
# 3          USCA  13431        14.0
# 4        Africa   6046         6.0

# %%
# Count Statistics of Categorical Variables
type_stats = pd.concat([df['Order Country'].value_counts(), df['Order Country'].value_counts(normalize=True).mul(100).round(0)], axis=1, keys=('count','percentage')).reset_index()
type_stats
# Out:
#          Order Country  count  percentage
# 0       Estados Unidos  12920        13.0
# 1              Francia   7624         8.0
# 2               MÈxico   7304         7.0
# 3             Alemania   5341         5.0
# 4            Australia   4488         5.0
# ..                 ...    ...         ...
# 157            Burundi      1         0.0
# 158             BarÈin      1         0.0
# 159  Guinea Ecuatorial      1         0.0
# 160             Kuwait      1         0.0
# 161              But·n      1         0.0
#
# [162 rows x 3 columns]

# %%
# Count Statistics of Categorical Variables
type_stats = pd.concat([df['Shipping Mode'].value_counts(), df['Shipping Mode'].value_counts(normalize=True).mul(100).round(0)], axis=1, keys=('count','percentage')).reset_index()
type_stats
# Out:
#     Shipping Mode  count  percentage
# 0  Standard Class  56800        58.0
# 1    Second Class  20460        21.0
# 2     First Class  15877        16.0
# 3        Same Day   5210         5.0

# %%
df_noncat.describe()
# Out:
#        Sales per customer  Order Item Cardprod Id         Sales  \
# count        98347.000000            98347.000000  98347.000000
# mean           175.757369              656.478439    195.677448
# std            118.809688              340.429902    131.113522
# min              7.490000               19.000000      9.990000
# 25%            103.989998              365.000000    119.980003
# 50%            161.970001              502.000000    199.949997
# 75%            235.160004              957.000000    250.000000
# max           1919.989990             1363.000000   1999.989990
#
#        Order Item Total  Product Price
# count      98347.000000   98347.000000
# mean         175.757369     136.593089
# std          118.809688     132.391620
# min            7.490000       9.990000
# 25%          103.989998      50.000000
# 50%          161.970001      99.989998
# 75%          235.160004     199.990005
# max         1919.989990    1999.989990

# %%
print(df.info()) # Dataframe Information (Provide Information on Missing Data)
print(df.describe())
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
print(variable_missing_data)
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
print(record_missing_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98347 entries, 0 to 98346
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Column1                 98347 non-null  int64
#  1   Type                    98347 non-null  object
#  2   Sales per customer      98347 non-null  float64
#  3   Customer Segment        98347 non-null  object
#  4   Market                  98347 non-null  object
#  5   Order Country           98347 non-null  object
#  6   Order Item Cardprod Id  98347 non-null  int64
#  7   Sales                   98347 non-null  float64
#  8   Order Item Total        98347 non-null  float64
#  9   Product Price           98347 non-null  float64
#  10  Shipping Mode           98347 non-null  object
#  11  cluster_number          98347 non-null  int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 9.0+ MB
# None
# ...

# %%
#Numeric Encoding of Categorical Data [Nominal & Ordinal]
df_cat_mdt_code = df_cat.copy()
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat_mdt_code)
df_cat_code_oe = pd.DataFrame(oe_fit, columns=['Type_code', 'Customer Segment_code', 'Market_code', 'Order Country_code', 'Shipping Mode_code']); df_cat_code_oe
df_cat_mdt_code_oe = df_cat_mdt_code.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat_mdt_code, df_cat_code_oe, left_index=True, right_index=True);
df_cat_mdt_code_oe
# Out:
#            Type Customer Segment        Market Order Country   Shipping Mode  \
# 0         DEBIT         Consumer  Pacific Asia     Indonesia  Standard Class
# 1      TRANSFER         Consumer  Pacific Asia         India  Standard Class
# 2          CASH         Consumer  Pacific Asia         India  Standard Class
# 3         DEBIT      Home Office  Pacific Asia     Australia  Standard Class
# 4       PAYMENT        Corporate  Pacific Asia     Australia  Standard Class
# ...         ...              ...           ...           ...             ...
# 98342     DEBIT      Home Office         LATAM        Brasil    Second Class
# 98343     DEBIT      Home Office         LATAM        MÈxico    Second Class
# 98344     DEBIT      Home Office         LATAM        MÈxico    Second Class
# 98345     DEBIT      Home Office         LATAM        MÈxico    Second Class
# 98346     DEBIT      Home Office  Pacific Asia     Indonesia    Second Class
#
# ...

# %%
#Box Plot for the outliers
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame and contains the columns you mentioned
df_noncat = df[['Sales per customer','Order Item Cardprod Id','Sales',
       'Order Item Total', 'Product Price']]

# Loop through each numerical column and create box plots
for column in df_noncat.columns:
    plt.figure(figsize=(4,4))
    sns.boxplot(y=df_noncat[column])
    plt.title(f'Boxplot of {column}')
    plt.ylabel(column)
    plt.show()

# %%
# 3.2.1. Normalization : Min-Max Scaling
df_noncat_mdt=df_noncat[['Sales per customer','Sales',
       'Order Item Total', 'Product Price']].copy()
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat_mdt)
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=df_noncat_mdt.columns+'_mn'); df_noncat_minmax_norm
df_noncat_mdt_mmn = pd.merge(df_noncat, df_noncat_minmax_norm, left_index=True, right_index=True); df_noncat_mdt_mmn
# Out:
#        Sales per customer  Order Item Cardprod Id       Sales  \
# 0              314.640015                    1360  327.750000
# 1              311.359985                    1360  327.750000
# 2              309.720001                    1360  327.750000
# 3              304.809998                    1360  327.750000
# 4              298.250000                    1360  327.750000
# ...                   ...                     ...         ...
# 98342          224.960007                     365  299.950012
# 98343          179.960007                     627  199.949997
# 98344          225.000000                     502  250.000000
# 98345          220.000000                     502  250.000000
# 98346          224.949997                     116  224.949997
#
#        Order Item Total  Product Price  Sales per customer_mn  Sales_mn  \
# 0            314.640015     327.750000               0.160601  0.159678
# 1            311.359985     327.750000               0.158886  0.159678
# ...

# %%
# Pre-Processed Dataset

# Using Scikit Learn Ordinal Encoder : df_cat_mdt_code_oe [Superior]

# Missing Data Treated & Transformed or Rescaled Non-Categorical Data Subsets

# Using Scikit Learn Standard Scaler : df_noncat_mdt_std [Standardization]


# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset

# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_mdt_mmn.copy(); df_noncat_ppd


# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd); df_ppd # Pre-Processed Dataset
df_ppd = pd.merge(df_cat_ppd, df_noncat_ppd, left_index=True, right_index=True); df_ppd
final_df = pd.merge(df_ppd, df[['cluster_number']], how='left', left_index=True, right_index=True)
print(final_df)
# Out:
#            Type Customer Segment        Market Order Country   Shipping Mode  \
# 0         DEBIT         Consumer  Pacific Asia     Indonesia  Standard Class
# 1      TRANSFER         Consumer  Pacific Asia         India  Standard Class
# 2          CASH         Consumer  Pacific Asia         India  Standard Class
# 3         DEBIT      Home Office  Pacific Asia     Australia  Standard Class
# 4       PAYMENT        Corporate  Pacific Asia     Australia  Standard Class
# ...         ...              ...           ...           ...             ...
# 98342     DEBIT      Home Office         LATAM        Brasil    Second Class
# 98343     DEBIT      Home Office         LATAM        MÈxico    Second Class
# 98344     DEBIT      Home Office         LATAM        MÈxico    Second Class
# 98345     DEBIT      Home Office         LATAM        MÈxico    Second Class
# 98346     DEBIT      Home Office  Pacific Asia     Indonesia    Second Class
#
# ...

# %%
# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset
#df_cat_ppd = df_cat_mdt_code_pd.copy(); df_cat_ppd
#df_cat_ppd = df_cat_mdt_code_le.copy(); df_cat_ppd
# Out:
#            Type Customer Segment        Market Order Country   Shipping Mode  \
# 0         DEBIT         Consumer  Pacific Asia     Indonesia  Standard Class
# 1      TRANSFER         Consumer  Pacific Asia         India  Standard Class
# 2          CASH         Consumer  Pacific Asia         India  Standard Class
# 3         DEBIT      Home Office  Pacific Asia     Australia  Standard Class
# 4       PAYMENT        Corporate  Pacific Asia     Australia  Standard Class
# ...         ...              ...           ...           ...             ...
# 98342     DEBIT      Home Office         LATAM        Brasil    Second Class
# 98343     DEBIT      Home Office         LATAM        MÈxico    Second Class
# 98344     DEBIT      Home Office         LATAM        MÈxico    Second Class
# 98345     DEBIT      Home Office         LATAM        MÈxico    Second Class
# 98346     DEBIT      Home Office  Pacific Asia     Indonesia    Second Class
#
# ...

# %%
# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_mdt_mmn.copy(); df_noncat_ppd # Preferred Data Subset
#df_noncat_ppd = df_noncat_mdt_rn.copy(); df_noncat_ppd
#df_noncat_ppd = df_noncat_mdt_std.copy(); df_noncat_ppd
#df_noncat_ppd = df_noncat_mdt_lt.copy(); df_noncat_ppd
# Out:
#        Sales per customer  Order Item Cardprod Id       Sales  \
# 0              314.640015                    1360  327.750000
# 1              311.359985                    1360  327.750000
# 2              309.720001                    1360  327.750000
# 3              304.809998                    1360  327.750000
# 4              298.250000                    1360  327.750000
# ...                   ...                     ...         ...
# 98342          224.960007                     365  299.950012
# 98343          179.960007                     627  199.949997
# 98344          225.000000                     502  250.000000
# 98345          220.000000                     502  250.000000
# 98346          224.949997                     116  224.949997
#
#        Order Item Total  Product Price  Sales per customer_mn  Sales_mn  \
# 0            314.640015     327.750000               0.160601  0.159678
# 1            311.359985     327.750000               0.158886  0.159678
# ...

# %%
# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd); df_ppd # Pre-Processed Dataset
final_df = pd.merge(df_ppd, df[['cluster_number']], how='left', left_index=True, right_index=True)
print(final_df)
#df_ppd = pd.merge(df_cat_ppd, df_noncat_ppd, left_index=True, right_index=True); df_ppd
# Out:
#            Type Customer Segment        Market Order Country   Shipping Mode  \
# 0         DEBIT         Consumer  Pacific Asia     Indonesia  Standard Class
# 1      TRANSFER         Consumer  Pacific Asia         India  Standard Class
# 2          CASH         Consumer  Pacific Asia         India  Standard Class
# 3         DEBIT      Home Office  Pacific Asia     Australia  Standard Class
# 4       PAYMENT        Corporate  Pacific Asia     Australia  Standard Class
# ...         ...              ...           ...           ...             ...
# 98342     DEBIT      Home Office         LATAM        Brasil    Second Class
# 98343     DEBIT      Home Office         LATAM        MÈxico    Second Class
# 98344     DEBIT      Home Office         LATAM        MÈxico    Second Class
# 98345     DEBIT      Home Office         LATAM        MÈxico    Second Class
# 98346     DEBIT      Home Office  Pacific Asia     Indonesia    Second Class
#
# ...

# %%
print(final_df.columns)
# Out:
# Index(['Type', 'Customer Segment', 'Market', 'Order Country', 'Shipping Mode',
#        'Type_code', 'Customer Segment_code', 'Market_code',
#        'Order Country_code', 'Shipping Mode_code', 'Sales per customer',
#        'Order Item Cardprod Id', 'Sales', 'Order Item Total', 'Product Price',
#        'Sales per customer_mn', 'Sales_mn', 'Order Item Total_mn',
#        'Product Price_mn', 'cluster_number'],
#       dtype='object')

# %%
final_new_df = final_df[['Type_code', 'Customer Segment_code', 'Market_code', 'Order Country_code', 'Shipping Mode_code', 'Sales per customer_mn', 'Sales_mn', 'Order Item Total_mn', 'Product Price_mn', 'cluster_number']]

# %%
# Import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree  # For Decision Tree Model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, classification_report # For Decision Tree Model Evaluation
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score
from matplotlib.colors import ListedColormap

# %%
from sklearn.model_selection import train_test_split

product_inputs = final_df[['Type_code', 'Customer Segment_code', 'Market_code', 'Shipping Mode_code', 'Sales per customer_mn', 'Sales_mn', 'Order Item Total_mn', 'Product Price_mn']]
product_output = final_df['cluster_number']  # No need for double brackets

product_inputs_names = product_inputs.columns
product_output_labels = product_output.unique().astype(str)

# %%
from sklearn.model_selection import StratifiedShuffleSplit
# Initialize StratifiedShuffleSplit with desired test size and random state
stratified_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45011)

# Perform the stratified split to get training and testing indices
for train_index, test_index in stratified_split.split(product_inputs, product_output):
    product_inputs_train, product_inputs_test = product_inputs.iloc[train_index], product_inputs.iloc[test_index]
    product_output_train, product_output_test = product_output.iloc[train_index], product_output.iloc[test_index]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
import numpy as np

# Initialize Logistic Regression model with L1 regularization
logreg_l1 = LogisticRegression(penalty='l1', solver='liblinear', random_state=45046)

# Fit the model on the training data
logreg_l1.fit(product_inputs_train, product_output_train.values.ravel())

# Get feature importances from the fitted model
feature_importances = np.abs(logreg_l1.coef_).flatten()

# Calculate the threshold as 20% of the maximum feature importance
threshold = 0.2 * np.max(feature_importances)

# Create a selector object to select features based on non-zero coefficients
selector = SelectFromModel(logreg_l1, threshold=threshold)

# Transform the training and testing input data to select features
product_inputs_train_selected = selector.transform(product_inputs_train)
product_inputs_test_selected = selector.transform(product_inputs_test)

# Get the selected features
selected_features = product_inputs_names[selector.get_support()]

# Print the selected features and the calculated threshold
print("Selected Features:", selected_features)
print("Threshold:", threshold)
# Out:
# Selected Features: Index(['Market_code', 'Sales_mn', 'Order Item Total_mn', 'Product Price_mn'], dtype='object')
# Threshold: 0.2883521692283798
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
# Decision Tree : Model (Training Subset)
dtc = DecisionTreeClassifier(criterion='gini', random_state=45046,max_depth=3) # Other Criteria : Entropy,  Log Loss
dtc_model = dtc.fit(product_inputs_train, product_output_train); dtc_model
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=45046)

# %%
# Decision Tree : Model Rules
dtc_model_rules = export_text(dtc_model, feature_names = list(product_inputs_names)); print(dtc_model_rules)
# Out:
# |--- Market_code <= 3.50
# |   |--- Market_code <= 0.50
# |   |   |--- Sales_mn <= 0.10
# |   |   |   |--- class: 1
# |   |   |--- Sales_mn >  0.10
# |   |   |   |--- class: 1
# |   |--- Market_code >  0.50
# |   |   |--- Market_code <= 2.50
# |   |   |   |--- class: 0
# |   |   |--- Market_code >  2.50
# |   |   |   |--- class: 2
# |--- Market_code >  3.50
# |   |--- Type_code <= 2.50
# |   |   |--- Type_code <= 0.50
# |   |   |   |--- class: 0
# |   |   |--- Type_code >  0.50
# |   |   |   |--- class: 0
# |   |--- Type_code >  2.50
# |   |   |--- Sales per customer_mn <= 0.20
# |   |   |   |--- class: 0
# |   |   |--- Sales per customer_mn >  0.20
# |   |   |   |--- class: 0

# %%
# Decision Tree : Feature Importance
dtc_imp_features = pd.DataFrame({'feature': product_inputs_names, 'importance': np.round(dtc_model.feature_importances_, 3)})
dtc_imp_features.sort_values('importance', ascending=False, inplace=True); dtc_imp_features
# Out:
#                  feature  importance
# 2            Market_code       0.999
# 0              Type_code       0.000
# 1  Customer Segment_code       0.000
# 3     Shipping Mode_code       0.000
# 4  Sales per customer_mn       0.000
# 5               Sales_mn       0.000
# 6    Order Item Total_mn       0.000
# 7       Product Price_mn       0.000

# %%
# Decision Tree : Model Prediction (Training Subset)
dtc_model_predict = dtc_model.predict(product_inputs_train); dtc_model_predict
# Out:
# array([2, 0, 0, ..., 1, 0, 0])

# %%
# Decision Tree : Prediction (Testing Subset)
dtc_predict = dtc_model.predict(product_inputs_test); dtc_predict
# Out:
# array([2, 0, 0, ..., 0, 0, 2])

# %%
# Decision Tree : Model Evaluation (Training Subset)
dtc_model_conf_mat = pd.DataFrame(confusion_matrix(product_output_train, dtc_model_predict)); dtc_model_conf_mat
dtc_model_perf = classification_report(product_output_train, dtc_model_predict); print(dtc_model_perf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.79      0.60     35192
#            1       0.71      0.14      0.23     24458
#            2       0.40      0.37      0.38     19027
#
#     accuracy                           0.48     78677
#    macro avg       0.53      0.43      0.41     78677
# weighted avg       0.54      0.48      0.44     78677

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Set a larger figure size for better clarity
plt.figure(figsize=(10, 10))

# Plot the decision tree
train_subset_dtc_plot = plot_tree(dtc_model, feature_names=product_inputs_names, class_names=product_output_labels, rounded=True, filled=True, fontsize=20)

# Show the plot
plt.show()

# %%
# Set up the plot
ax = plt.axes()

# Plot the confusion matrix with annotations in integer format
sns.heatmap(dtc_model_conf_mat, annot=True, fmt='d', cmap='Paired')

# Set labels and title
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')

# Show the plot
plt.show()

# %%
# Cross Validation
from sklearn.model_selection import cross_val_score

# Define your decision tree classifier with desired parameters
dtc_cv = DecisionTreeClassifier(criterion='gini', random_state=45046)

# Perform 5-fold cross-validation
cv_scores = cross_val_score(dtc_cv, product_inputs, product_output.values.ravel(), cv=20)
print("Cross-Validation Scores:", cv_scores)
print("Average Cross-Validation Score:", np.mean(cv_scores))
# Out:
# Cross-Validation Scores: [0.39467263 0.4442863  0.40626271 0.44611631 0.43920293 0.40219601
#  0.36783245 0.37766931 0.36851739 0.41976815 0.39821029 0.4049217
#  0.33272321 0.43258084 0.42892007 0.34492577 0.44539353 0.32357128
#  0.39109213 0.46410413]
# Average Cross-Validation Score: 0.4016483570333828

# %%
from sklearn.metrics import f1_score

# Compute F1 score
f1 = f1_score(product_output_test, dtc_predict, average='macro')  # or 'weighted' for weighted F1 score
print("F1 Score:", f1)

# Weighted F1 score
weighted_f1 = f1_score(product_output_test, dtc_predict, average='weighted')
print("Weighted F1 Score:", weighted_f1)
# Out:
# F1 Score: 0.41083759983517004
# Weighted F1 Score: 0.43879471679325305

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, cross_val_score
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
import numpy as np
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Your code for data preprocessing and model training goes here...

# End time
end_time = time.time()

# Time taken
execution_time = end_time - start_time

# Memory usage
memory_used = memory_usage()

# Print memory usage and execution time
print("Memory used (MB):", memory_used)
print("Time taken (seconds):", execution_time)

# Make predictions using the trained model and measure accuracy
# Assuming you have already trained your decision tree model (dtc_model) and logistic regression model (logreg_l1)
# For example:

# Decision Tree predictions and evaluation
dtc_predict_train = dtc_model.predict(product_inputs_train)
dtc_predict_test = dtc_model.predict(product_inputs_test)

# Calculate accuracy for decision tree
accuracy_dtc_train = accuracy_score(product_output_train, dtc_predict_train)
accuracy_dtc_test = accuracy_score(product_output_test, dtc_predict_test)


# Print accuracy
print("Decision Tree Training Accuracy:", accuracy_dtc_train)
print("Decision Tree Testing Accuracy:", accuracy_dtc_test)
# Out:
# Memory used (MB): 440.3359375
# Time taken (seconds): 3.647804260253906e-05
# Decision Tree Training Accuracy: 0.4837881464722854
# Decision Tree Testing Accuracy: 0.4854600915099136

# %% [markdown]
# # **Random Forest**

# %%
## Data Visualization Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from wordcloud import WordCloud
from collections import Counter
from scipy import stats
from sklearn.tree import plot_tree
import graphviz
from IPython.display import display
from collections import Counter

## Machine Learning Models and Evaluation Metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.validation import column_or_1d
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, precision_recall_fscore_support
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression, Lasso, Ridge
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.tree import export_graphviz

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=45046)

# %%
print(product_output_train.unique())
# Out:
# [2 0 1]

# %%
rf_classifier.fit(product_inputs_train, product_output_train)
# Out:
# RandomForestClassifier(random_state=45046)

# %%
y_train_pred_rf = rf_classifier.predict(product_inputs_train)
y_test_pred_rf = rf_classifier.predict(product_inputs_test)

# %%
# Train the Random Forest classifier
rf_classifier.fit(product_inputs_train, product_output_train)

# Print feature importances
feature_importances = rf_classifier.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': product_inputs_train.columns, 'Importance': feature_importances})
sorted_feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
print("Feature Importances:")
print(sorted_feature_importance_df)
# Out:
# Feature Importances:
#                  Feature  Importance
# 2            Market_code    0.244833
# 4  Sales per customer_mn    0.201121
# 6    Order Item Total_mn    0.200783
# 0              Type_code    0.103565
# 3     Shipping Mode_code    0.083606
# 1  Customer Segment_code    0.060216
# 5               Sales_mn    0.053833
# 7       Product Price_mn    0.052043

# %%
# For training set
print("Training Set Confusion Matrix:")
print(confusion_matrix(product_output_train, y_train_pred_rf))

print("\nTraining Set Classification Report:")
print(classification_report(product_output_train, y_train_pred_rf))
# Out:
# Training Set Confusion Matrix:
# [[29290  3624  2278]
#  [ 3739 18734  1985]
#  [ 3558  2967 12502]]
#
# Training Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.82     35192
#            1       0.74      0.77      0.75     24458
#            2       0.75      0.66      0.70     19027
#
#     accuracy                           0.77     78677
#    macro avg       0.76      0.75      0.76     78677
# weighted avg       0.77      0.77      0.77     78677

# %%
# For testing set
print("\nTesting Set Confusion Matrix:")
print(confusion_matrix(product_output_test, y_test_pred_rf))

print("\nTesting Set Classification Report:")
print(classification_report(product_output_test, y_test_pred_rf))
# Out:
# Testing Set Confusion Matrix:
# [[5229 2048 1521]
#  [2061 2851 1203]
#  [1926 1504 1327]]
#
# Testing Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.59      0.58      8798
#            1       0.45      0.47      0.46      6115
#            2       0.33      0.28      0.30      4757
#
#     accuracy                           0.48     19670
#    macro avg       0.45      0.45      0.45     19670
# weighted avg       0.47      0.48      0.47     19670

# %%
# Assuming rf is your trained Random Forest classifier
for i in range(3):
    tree = rf_classifier.estimators_[i]  # Assuming rf_classifier is your trained Random Forest model
    dot_data = export_graphviz(tree,
                               feature_names=product_inputs_train.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
# Export and visualize the first three decision trees
for i in range(3):
    tree = rf_classifier.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=product_inputs_train.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
# Initialize a dictionary to store tree frequencies and rules
tree_frequency = Counter()
tree_rules = {}

# Loop through the trees and count their frequency while storing rules
for i in range(len(rf_classifier.estimators_)):
    tree = rf_classifier.estimators_[i]
    tree_str = export_text(tree, feature_names=list(product_inputs_train.columns))
    tree_frequency[tree_str] += 1
    tree_rules[tree_str] = tree

# Get the three most frequent trees
top_trees = tree_frequency.most_common(3)

# Print the rules for the top three trees
for tree_str, frequency in top_trees:
    print(f"Tree Frequency: {frequency}")
    print(tree_str)
    print("\n")
# Out:
# Tree Frequency: 1
# |--- Product Price_mn <= 0.15
# |   |--- Product Price_mn <= 0.00
# |   |   |--- Sales per customer_mn <= 0.00
# |   |   |   |--- Type_code <= 2.50
# |   |   |   |   |--- Sales per customer_mn <= 0.00
# |   |   |   |   |   |--- Type_code <= 0.50
# |   |   |   |   |   |   |--- Sales per customer_mn <= 0.00
# |   |   |   |   |   |   |   |--- Shipping Mode_code <= 1.50
# |   |   |   |   |   |   |   |   |--- class: 0.0
# |   |   |   |   |   |   |   |--- Shipping Mode_code >  1.50
# |   |   |   |   |   |   |   |   |--- Product Price_mn <= 0.00
# |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |--- Product Price_mn >  0.00
# |   |   |   |   |   |   |   |   |   |--- Shipping Mode_code <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- Product Price_mn <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2.0
# |   |   |   |   |   |   |   |   |   |   |--- Product Price_mn >  0.00
# ...

# %%
# Initialize a dictionary to store tree frequencies
tree_frequency = Counter()

# Loop through the trees and count their frequency
for i in range(len(rf_classifier.estimators_)):
    tree = rf_classifier.estimators_[i]
    tree_str = export_graphviz(tree, feature_names=product_inputs_train.columns,
                               filled=True, max_depth=2, impurity=False, proportion=True)
    tree_frequency[tree_str] += 1

# Get the three most frequent trees
top_trees = tree_frequency.most_common(3)

# Plot the top three trees
for tree_str, frequency in top_trees:
    graph = graphviz.Source(tree_str)
    display(graph)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from wordcloud import WordCloud
from collections import Counter
from scipy import stats
from sklearn.tree import plot_tree, export_graphviz
import graphviz
from IPython.display import display
from collections import Counter
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Initialize Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=45011)

# Train the Random Forest classifier
rf_classifier.fit(product_inputs_train, product_output_train)

# Predictions
y_train_pred_rf = rf_classifier.predict(product_inputs_train)
y_test_pred_rf = rf_classifier.predict(product_inputs_test)

# End time
end_time = time.time()

# Time taken
execution_time = end_time - start_time

# Memory usage
memory_used = memory_usage()

# Accuracy
accuracy_train = accuracy_score(product_output_train, y_train_pred_rf)
accuracy_test = accuracy_score(product_output_test, y_test_pred_rf)

# Print time, memory usage, and accuracy
print("Time taken (seconds):", execution_time)
print("Memory used (MB):", memory_used)
print("Training Set Accuracy:", accuracy_train)
print("Testing Set Accuracy:", accuracy_test)

# Print feature importances
feature_importances = rf_classifier.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': product_inputs_train.columns, 'Importance': feature_importances})
sorted_feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
print("\nFeature Importances:")
print(sorted_feature_importance_df)

# Print confusion matrix and classification report for training set
print("\nTraining Set Confusion Matrix:")
print(confusion_matrix(product_output_train, y_train_pred_rf))
print("\nTraining Set Classification Report:")
print(classification_report(product_output_train, y_train_pred_rf))

# Print confusion matrix and classification report for testing set
print("\nTesting Set Confusion Matrix:")
print(confusion_matrix(product_output_test, y_test_pred_rf))
print("\nTesting Set Classification Report:")
print(classification_report(product_output_test, y_test_pred_rf))

# Export and visualize the first three decision trees
for i in range(3):
    tree = rf_classifier.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=product_inputs_train.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# Initialize a dictionary to store tree frequencies and rules
tree_frequency = Counter()
tree_rules = {}

# Loop through the trees and count their frequency while storing rules
for i in range(len(rf_classifier.estimators_)):
    tree = rf_classifier.estimators_[i]
    tree_str = export_text(tree, feature_names=list(product_inputs_train.columns))
    tree_frequency[tree_str] += 1
    tree_rules[tree_str] = tree

# Get the three most frequent trees
top_trees = tree_frequency.most_common(3)

# Print the rules for the top three trees
for tree_str, frequency in top_trees:
    print(f"Tree Frequency: {frequency}")
    print(tree_str)
    print("\n")

# Initialize a dictionary to store tree frequencies
tree_frequency = Counter()

# Loop through the trees and count their frequency
for i in range(len(rf_classifier.estimators_)):
    tree = rf_classifier.estimators_[i]
    tree_str = export_graphviz(tree, feature_names=product_inputs_train.columns,
                               filled=True, max_depth=2, impurity=False, proportion=True)
    tree_frequency[tree_str] += 1

# Get the three most frequent trees
top_trees = tree_frequency.most_common(3)

# Plot the top three trees
for tree_str, frequency in top_trees:
    graph = graphviz.Source(tree_str)
    display(graph)
# Out:
# Time taken (seconds): 15.762568712234497
# Memory used (MB): 1101.8203125
# Training Set Accuracy: 0.7692845431320462
# Testing Set Accuracy: 0.4780884595831215
#
# Feature Importances:
#                  Feature  Importance
# 2            Market_code    0.243864
# 4  Sales per customer_mn    0.201483
# 6    Order Item Total_mn    0.201098
# 0              Type_code    0.101976
# 3     Shipping Mode_code    0.082371
# 1  Customer Segment_code    0.064665
# 5               Sales_mn    0.053162
# 7       Product Price_mn    0.051381
#
# Training Set Confusion Matrix:
# [[29293  3667  2232]
#  [ 3745 18801  1912]
#  [ 3545  3051 12431]]
#
# Training Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.82     35192
#            1       0.74      0.77      0.75     24458
#            2       0.75      0.65      0.70     19027
#
#     accuracy                           0.77     78677
# ...

# %%
import pandas as pd
import numpy as np
import time
import psutil
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Data preprocessing and splitting
# Assuming you have your data loaded into product_inputs and product_output
product_inputs_train, product_inputs_test, product_output_train, product_output_test = train_test_split(product_inputs, product_output, test_size=0.2, random_state=42)

# Initialize lists to store results
models = []
training_times = []
memory_used = []
single_split_accuracies = []
cross_validation_accuracies = []

# Decision Tree
dt_start_time = time.time()
dt_model = DecisionTreeClassifier(criterion='gini', random_state=45011, max_depth=3)
dt_model.fit(product_inputs_train, product_output_train)
dt_training_time = time.time() - dt_start_time
dt_memory_used = memory_usage()
dt_pred = dt_model.predict(product_inputs_test)
dt_accuracy = accuracy_score(product_output_test, dt_pred)

# Cross-validation for Decision Tree
dtc_cv_start_time = time.time()
dtc_cv = DecisionTreeClassifier(criterion='gini', random_state=45011)
cv_scores_dtc = cross_val_score(dtc_cv, product_inputs, product_output.values.ravel(), cv=20)
dtc_cv_time = time.time() - dtc_cv_start_time
dtc_cv_accuracy = np.mean(cv_scores_dtc)

# Append Decision Tree results to lists
models.append('Decision Tree')
training_times.append(dt_training_time)
memory_used.append(dt_memory_used)
single_split_accuracies.append(dt_accuracy)
cross_validation_accuracies.append(dtc_cv_accuracy)

# Random Forest
rf_start_time = time.time()
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=45011)
rf_classifier.fit(product_inputs_train, product_output_train)
rf_training_time = time.time() - rf_start_time
rf_memory_used = memory_usage()
y_train_pred_rf = rf_classifier.predict(product_inputs_train)
y_test_pred_rf = rf_classifier.predict(product_inputs_test)
rf_accuracy_train = accuracy_score(product_output_train, y_train_pred_rf)
rf_accuracy_test = accuracy_score(product_output_test, y_test_pred_rf)

# Append Random Forest results to lists
models.append('Random Forest')
training_times.append(rf_training_time)
memory_used.append(rf_memory_used)
single_split_accuracies.append(rf_accuracy_test)  # Using test accuracy as we already calculated it
cross_validation_accuracies.append(np.nan)  # Cross-validation accuracy not calculated here

# Create DataFrame
results_df = pd.DataFrame({
    'Model': models,
    'Training Time (s)': training_times,
    'Memory Used (MB)': memory_used,
    'Single Split Accuracy': single_split_accuracies,
    'Cross Validation Accuracy': cross_validation_accuracies
})

# Print DataFrame
print(results_df)
# Out:
#            Model  Training Time (s)  Memory Used (MB)  Single Split Accuracy  \
# 0  Decision Tree           0.119032       1109.039062               0.487290
# 1  Random Forest          11.900504       1427.628906               0.478444
#
#    Cross Validation Accuracy
# 0                   0.401221
# 1                        NaN
